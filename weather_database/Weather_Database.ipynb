# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 769

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=12f636f63349a3a0857157186c4992dc

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
cities
# Out:
# ['acapulco',
#  'chokurdakh',
#  'provideniya',
#  'berdigestyakh',
#  'busselton',
#  'whyalla',
#  'bodden town',
#  'namibe',
#  'qaanaaq',
#  'coquimbo',
#  'alihe',
#  'hilo',
#  'ushuaia',
#  'pontianak',
#  'ternate',
#  'suslovo',
#  'xadani',
#  'sinnamary',
#  'geraldton',
#  'fortuna',
#  'simoes',
#  'port alfred',
#  'rikitea',
#  'mataura',
#  'saskylakh',
#  'atuona',
#  'ola',
#  'naze',
#  'husavik',
#  'guymon',
#  'bambous virieux',
#  'natal',
#  'mar del plata',
#  'punta arenas',
#  'taolanaro',
#  'merrill',
#  'lasa',
#  'hermanus',
#  'gao',
#  'tuktoyaktuk',
#  'nantucket',
#  'carnarvon',
#  'beringovskiy',
#  'tucuma',
#  'aden',
#  'cape town',
#  'barrow',
#  'albany',
#  'bredasdorp',
#  'bluff',
#  'mys shmidta',
#  'kahului',
#  'nikolskoye',
#  'wulanhaote',
#  'sabha',
#  'mount pleasant',
#  'grand river south east',
#  'saleaula',
#  'sadasivpet',
#  'illoqqortoormiut',
#  'taltal',
#  'lagoa',
#  'warqla',
#  'klaksvik',
#  'tasiilaq',
#  'tabas',
#  'castro',
#  'augusto correa',
#  'nara',
#  'tuatapere',
#  'jamestown',
#  'bud',
#  'vardo',
#  'cherskiy',
#  'kodiak',
#  'alyangula',
#  'port lincoln',
#  'upernavik',
#  'roela',
#  'arraial do cabo',
#  'attawapiskat',
#  'puri',
#  'kaitangata',
#  'atambua',
#  'lebu',
#  'raga',
#  'mount gambier',
#  'hobart',
#  'zhuhai',
#  'vaini',
#  'san pedro de uraba',
#  'harper',
#  'kapaa',
#  'baley',
#  'anadyr',
#  'ayolas',
#  'abu samrah',
#  'haines junction',
#  'thompson',
#  'rulenge',
#  'walvis bay',
#  'ornskoldsvik',
#  'georgetown',
#  'palabuhanratu',
#  'poum',
#  'qasigiannguit',
#  'gorele',
#  'solwezi',
#  'yellowknife',
#  'seoul',
#  'asau',
#  'hun',
#  'pimentel',
#  'avarua',
#  'codrington',
#  'barcelos',
#  'puerto ayora',
#  'ribeira grande',
#  'clyde river',
#  'el campo',
#  'kismayo',
#  'dikson',
#  'olafsvik',
#  'port hedland',
#  'talnakh',
#  'neiafu',
#  'toliary',
#  'east london',
#  'belushya guba',
#  'ostrovnoy',
#  'avera',
#  'nicoya',
#  'souillac',
#  'aykhal',
#  'thinadhoo',
#  'srednekolymsk',
#  'ambanja',
#  'new norfolk',
#  'kostyantynivka',
#  'ust-koksa',
#  'palaia fokaia',
#  'saint-philippe',
#  'yambio',
#  'sentyabrskiy',
#  'xuddur',
#  'preobrazheniye',
#  'barentsburg',
#  'ansalta',
#  'siniscola',
#  'severo-kurilsk',
#  'hasaki',
#  'tondon',
#  'la palma',
#  'hithadhoo',
#  'saint-augustin',
#  'launceston',
#  'rocha',
#  'mahebourg',
#  'saint-pierre',
#  'plettenberg bay',
#  'aljustrel',
#  'mana',
#  'malanje',
#  'tautira',
#  'iqaluit',
#  'hami',
#  'san juan',
#  'cayenne',
#  'sulangan',
#  'richards bay',
#  'inverell',
#  'brandfort',
#  'chagda',
#  'alofi',
#  'copiapo',
#  'katsuura',
#  'namatanai',
#  'cidreira',
#  'digras',
#  'temaraia',
#  'blagoyevo',
#  'ahipara',
#  'bethel',
#  'bauchi',
#  'sovetskiy',
#  'vao',
#  'gariaband',
#  'maragogi',
#  'storforshei',
#  'nuuk',
#  'beauceville',
#  'ancud',
#  'tsihombe',
#  'broken hill',
#  'kuhdasht',
#  'emmaus',
#  'gat',
#  'constitucion',
#  'playia',
#  'samusu',
#  'batagay-alyta',
#  'toribio',
#  'cervo',
#  'guerrero negro',
#  'padang',
#  'xiaoweizhai',
#  'chipinge',
#  'natalinsk',
#  'pevek',
#  'surenavan',
#  'bairiki',
#  'anlu',
#  'beira',
#  'yerofey pavlovich',
#  'narsaq',
#  'masuguru',
#  'leningradskiy',
#  'ponta do sol',
#  'daru',
#  'houma',
#  'khatanga',
#  'bathsheba',
#  'maniitsoq',
#  'hurricane',
#  'sorong',
#  'havoysund',
#  'zhuozhou',
#  'dunedin',
#  'orje',
#  'sola',
#  'san quintin',
#  'longyearbyen',
#  'opuwo',
#  'vaitupu',
#  'butaritari',
#  'placido de castro',
#  'nanortalik',
#  'marcona',
#  'tortoli',
#  'kloulklubed',
#  'faanui',
#  'isangel',
#  'kuusamo',
#  'caravelas',
#  'iskateley',
#  'shingu',
#  'airai',
#  'sungairaya',
#  'santa maria',
#  'cabo san lucas',
#  'karangasem',
#  'ngong',
#  'portland',
#  'buraydah',
#  'vila velha',
#  'bataraza',
#  'mangan',
#  'ayr',
#  'severnoye',
#  'esperance',
#  'kindu',
#  'torbay',
#  'quesnel',
#  'goderich',
#  'lewistown',
#  'touros',
#  'bushenyi',
#  'tezu',
#  'paciran',
#  'quelimane',
#  'fairbanks',
#  'flin flon',
#  'verkhnyaya inta',
#  'west bay',
#  'coihaique',
#  'zhenlai',
#  'riyadh',
#  'kutum',
#  'ketchikan',
#  'ha tinh',
#  'ilulissat',
#  'marsh harbour',
#  'gerash',
#  'davila',
#  'nouadhibou',
#  'thiers',
#  'cheney',
#  'malwan',
#  'aklavik',
#  'harnosand',
#  'jalu',
#  'mount hagen',
#  'benguela',
#  'cape coast',
#  'pueblo',
#  'rio gallegos',
#  'yarmouth',
#  'nanning',
#  'victoria',
#  'galesong',
#  'belmonte',
#  'labuhan',
#  'chernyshevskiy',
#  'bopfingen',
#  'cap malheureux',
#  'kenai',
#  'hambantota',
#  'nguiu',
#  'barawe',
#  'vaitape',
#  'mahanje',
#  'goya',
#  'say',
#  'oranjemund',
#  'hopkinsville',
#  'verkhoyansk',
#  'pangnirtung',
#  'kamaishi',
#  'havelock',
#  'asfi',
#  'chernyshevsk',
#  'muswellbrook',
#  'henties bay',
#  'itacare',
#  'berlevag',
#  'dale',
#  'narsipatnam',
#  'alice springs',
#  'sorland',
#  'maceio',
#  'canon city',
#  'port hardy',
#  'dudinka',
#  'faya',
#  'zhigansk',
#  'amderma',
#  'madera',
#  'glendive',
#  'hualmay',
#  'bria',
#  'sao filipe',
#  'pombia',
#  'tiznit',
#  'macaubas',
#  'rudnogorsk',
#  'micheweni',
#  'nadym',
#  'lagos',
#  'udachnyy',
#  'mikuni',
#  'puerto madryn',
#  'luderitz',
#  'luwingu',
#  'saldanha',
#  'vestmannaeyjar',
#  'shamilkala',
#  'smithers',
#  'nizhneyansk',
#  'ano mera',
#  'saint anthony',
#  'estelle',
#  'menongue',
#  'ceska kamenice',
#  'palu',
#  'hay river',
#  'tadine',
#  'qaqortoq',
#  'sarkand',
#  'port augusta',
#  'sarny',
#  'vestmanna',
#  'pringsewu',
#  'lakes entrance',
#  'ambikapur',
#  'belaya gora',
#  'polkowice',
#  'atbasar',
#  'causapscal',
#  'college',
#  'sarangani',
#  'comodoro rivadavia',
#  'aljezur',
#  'suzu',
#  'rancho palos verdes',
#  'udaipur',
#  'luis correia',
#  'te anau',
#  'grand gaube',
#  'kalengwa',
#  'coahuayana',
#  'mahibadhoo',
#  'lovozero',
#  'bengkulu',
#  'lerwick',
#  'mocambique',
#  'japura',
#  'vero beach',
#  'arona',
#  'kruisfontein',
#  'wote',
#  'lebedinyy',
#  'medea',
#  'moranbah',
#  'bargal',
#  'wakema',
#  'iranshahr',
#  'timiryazevskiy',
#  'ploemeur',
#  'ous',
#  'mangrol',
#  'vieux-habitants',
#  'yenagoa',
#  'cabra',
#  'yar-sale',
#  'khonuu',
#  'macau',
#  'tres arroyos',
#  'cairns',
#  'myaundzha',
#  'yuancheng',
#  'pemangkat',
#  'kanniyakumari',
#  'tynda',
#  'chone',
#  'urucara',
#  'lompoc',
#  'kokstad',
#  'bereda',
#  'kavieng',
#  'boffa',
#  'san patricio',
#  'necochea',
#  'vostok',
#  'isilkul',
#  'joshimath',
#  'barbar',
#  'itarema',
#  'joao pinheiro',
#  'san cristobal',
#  'kapit',
#  'gardan diwal',
#  'salinopolis',
#  'saint-louis',
#  'banepa',
#  'cocachacra',
#  'cascais',
#  'poya',
#  'lavrentiya',
#  'paita',
#  'fare',
#  'hastings',
#  'stoyba',
#  'kota belud',
#  'cortez',
#  'grootfontein',
#  'saint-joseph',
#  'sumbawa',
#  'kamina',
#  'tecoanapa',
#  'chuy',
#  'ust-kulom',
#  'lamin',
#  'kudahuvadhoo',
#  'ngukurr',
#  'bang saphan',
#  'del rio',
#  'takoradi',
#  'ponta delgada',
#  'yirol',
#  'chino valley',
#  'mackay',
#  'belmopan',
#  'suileng',
#  'tiksi',
#  'sint michiel',
#  'qandahar',
#  'whitianga',
#  'burayevo',
#  'buala',
#  'mihail eminescu',
#  'norman wells',
#  'sambava',
#  'wajima',
#  'cravo norte',
#  'melbourne',
#  'lobatse',
#  'bethanien',
#  'laguna',
#  'lensk',
#  'chumikan',
#  'cabimas',
#  'akcakoca',
#  'brylivka',
#  'presidencia roque saenz pena',
#  'san policarpo',
#  'porto novo',
#  'pavlivka',
#  'kushima',
#  'soto la marina',
#  'dabat',
#  'torbat-e jam',
#  'timizart',
#  'waikuku',
#  'borovoy',
#  'aswan',
#  'lethem',
#  'capitao poco',
#  'dwarka',
#  'bandarbeyla',
#  'sayat',
#  'bukachacha',
#  'san ramon',
#  'warri',
#  'kalianget',
#  'brand-erbisdorf',
#  'viransehir',
#  'pochutla',
#  'altoona',
#  'te karaka',
#  'salisbury',
#  'santa vitoria do palmar',
#  'westport',
#  'obihiro',
#  'lobito',
#  'rosarito',
#  'saint george',
#  'luziania',
#  'meulaboh',
#  'giyon',
#  'gornopravdinsk',
#  'neyshabur',
#  'port blair',
#  'port elizabeth',
#  'iwanai',
#  'palmer',
#  'beidao',
#  'conchal',
#  'mitsamiouli',
#  'kholmogory',
#  'ust-kan',
#  'maple creek',
#  'mount isa',
#  'belyy yar',
#  'tsuruoka',
#  'nueva loja',
#  'yumen',
#  'boa vista',
#  'adeje',
#  'agirish',
#  'dauphin',
#  'komsomolsk-na-amure',
#  'kupang',
#  'malakal',
#  'baruun-urt',
#  'oriximina',
#  'sitka',
#  'gotsu',
#  'santa rosa',
#  'kihei',
#  'biltine',
#  'nambucca heads',
#  'preeceville',
#  'yeppoon',
#  'salalah',
#  'myitkyina',
#  'brae',
#  'byron bay',
#  'tlahualilo',
#  'hurghada',
#  'phalombe',
#  'porto walter',
#  'dongsheng',
#  'kimbe',
#  'solhan',
#  'liverpool',
#  'aasiaat',
#  'escanaba',
#  'vila franca do campo',
#  'rishra',
#  'dobeln',
#  'hamada',
#  'kununurra',
#  'kavaratti',
#  'barranco',
#  'ordzhonikidze',
#  'tarrafal',
#  'wewak',
#  'fukue',
#  'wonthaggi',
#  'lucapa',
#  'glens falls',
#  'magistralnyy',
#  'half moon bay',
#  'muli',
#  'poquoson',
#  'orlik',
#  'visby',
#  'sacile',
#  'beecher',
#  'marfino',
#  'mabaruma',
#  'palembang',
#  'saint-francois',
#  'matara',
#  'kieta',
#  'itaqui',
#  'yulara',
#  'paamiut',
#  'obigarm',
#  'dukat',
#  'douglas',
#  'meylan',
#  'najran',
#  'artyk',
#  'wassenaar',
#  'sao joao da barra',
#  'omboue',
#  'hazorasp',
#  'lushunkou',
#  'champerico',
#  'calabozo',
#  'kodinsk',
#  'bonavista',
#  'easton',
#  'upington',
#  'castlegar',
#  'biak',
#  'kensington',
#  'trat',
#  'solton',
#  'johi',
#  'louisbourg',
#  'kokopo',
#  'manuk mangkaw',
#  'shubarkuduk',
#  'umzimvubu',
#  'mahina',
#  'quatre cocos',
#  'zeya',
#  'yellamanchili',
#  'jackson',
#  'bowen',
#  'karadaglije',
#  'buckeye',
#  'marsaxlokk',
#  'talas',
#  'bonoua',
#  'talara',
#  'canandaigua',
#  'doka',
#  'porto uniao',
#  'nouakchott',
#  'mormugao',
#  'voiron',
#  'mul',
#  'hovd',
#  'severnyy',
#  'obernai',
#  'papar',
#  'athabasca',
#  'nome',
#  'gamba',
#  'man',
#  'myskhako',
#  'pangody',
#  'katangli',
#  'poim',
#  'sumkino',
#  'dingle',
#  'usinsk',
#  'bougouni',
#  'victor harbor',
#  'angoche',
#  'potosi',
#  'pochinok',
#  'andros town',
#  'ust-kut',
#  'choix',
#  'nizhnyaya tavda',
#  'tabiauea',
#  'kristiansund',
#  'ripky',
#  'the valley',
#  'zhezkazgan',
#  'montepuez',
#  'polunochnoye',
#  'anzio',
#  'zhangjiakou',
#  'ghanzi',
#  'kuching',
#  'sao bento',
#  'susanville',
#  'solnechnyy',
#  'thunder bay',
#  'marzuq',
#  'aquiraz',
#  'cafarnaum',
#  'tarudant',
#  'kamenka',
#  'quchan',
#  'phayao',
#  'abu zabad',
#  'barranca',
#  'puerto escondido',
#  'ushtobe',
#  'merritt island',
#  'surt',
#  'tigil',
#  'kaka',
#  'kaffrine',
#  'katiola',
#  'mgachi',
#  'dillon',
#  'pacific grove',
#  'panguna',
#  'toulepleu',
#  'havre-saint-pierre',
#  'krasnyy yar',
#  'kurilsk',
#  'dayong',
#  'grand island',
#  'springbok',
#  'sumbe',
#  'naberera',
#  'kaeo',
#  'oblivskaya',
#  'hamilton',
#  'rabo de peixe',
#  'skjervoy',
#  'miyang',
#  'yantal',
#  'lata',
#  'filadelfia',
#  'sibolga',
#  'petropavl',
#  'cacu',
#  'cachoeira',
#  'beaupre',
#  'ossora',
#  'korla',
#  'diu',
#  'lagunillas',
#  'goundi',
#  'grindavik',
#  'muros',
#  'banmo',
#  'ballina',
#  'stonewall',
#  'megion',
#  'tumannyy',
#  'antibes',
#  'kegayli',
#  'badiraguato',
#  'casma',
#  'kanye',
#  'albuquerque',
#  'aflu',
#  'luau',
#  'iskilip',
#  'leh',
#  'santa cruz de la palma',
#  'boyolangu',
#  'iaciara',
#  'camana',
#  'teknaf',
#  'mehamn',
#  'palampur',
#  'visnes',
#  'leshukonskoye']

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        print(city_weather)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | acapulco
# {'coord': {'lon': -99.8901, 'lat': 16.8634}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 82.22, 'feels_like': 87.8, 'temp_min': 82.22, 'temp_max': 82.22, 'pressure': 1012, 'humidity': 74}, 'visibility': 9656, 'wind': {'speed': 8.05, 'deg': 280}, 'clouds': {'all': 75}, 'dt': 1665022129, 'sys': {'type': 1, 'id': 7103, 'country': 'MX', 'sunrise': 1664973012, 'sunset': 1665015927}, 'timezone': -18000, 'id': 3533462, 'name': 'Acapulco de Juárez', 'cod': 200}
# Processing Record 2 of Set 1 | chokurdakh
# {'coord': {'lon': 147.9167, 'lat': 70.6333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 21.4, 'feels_like': 11.86, 'temp_min': 21.4, 'temp_max': 21.4, 'pressure': 997, 'humidity': 89, 'sea_level': 997, 'grnd_level': 993}, 'visibility': 1346, 'wind': {'speed': 8.1, 'deg': 337, 'gust': 12.01}, 'clouds': {'all': 97}, 'dt': 1665022260, 'sys': {'country': 'RU', 'sunrise': 1665002585, 'sunset': 1665040195}, 'timezone': 39600, 'id': 2126123, 'name': 'Chokurdakh', 'cod': 200}
# Processing Record 3 of Set 1 | provideniya
# {'coord': {'lon': -173.3, 'lat': 64.3833}, 'weather': [{'id': 520, 'main': 'Rain', 'description': 'light intensity shower rain', 'icon': '09n'}, {'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 41.11, 'feels_like': 28.51, 'temp_min': 41.11, 'temp_max': 41.36, 'pressure': 993, 'humidity': 100}, 'visibility': 4000, 'wind': {'speed': 40, 'deg': 170, 'gust': 65.01}, 'clouds': {'all': 100}, 'dt': 1665022260, 'sys': {'type': 1, 'id': 8875, 'country': 'RU', 'sunrise': 1665079062, 'sunset': 1665117869}, 'timezone': 43200, 'id': 4031574, 'name': 'Provideniya', 'cod': 200}
# Processing Record 4 of Set 1 | berdigestyakh
# {'coord': {'lon': 126.6992, 'lat': 62.0989}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 29.62, 'feels_like': 22.75, 'temp_min': 29.62, 'temp_max': 29.62, 'pressure': 1006, 'humidity': 88, 'sea_level': 1006, 'grnd_level': 980}, 'visibility': 374, 'wind': {'speed': 6.85, 'deg': 307, 'gust': 14.81}, 'snow': {'1h': 0.25}, 'clouds': {'all': 100}, 'dt': 1665022260, 'sys': {'country': 'RU', 'sunrise': 1665006712, 'sunset': 1665046250}, 'timezone': 32400, 'id': 2026861, 'name': 'Berdigestyakh', 'cod': 200}
# Processing Record 5 of Set 1 | busselton
# {'coord': {'lon': 115.3333, 'lat': -33.65}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 57.42, 'feels_like': 55.78, 'temp_min': 57.42, 'temp_max': 57.42, 'pressure': 1022, 'humidity': 62, 'sea_level': 1022, 'grnd_level': 1021}, 'visibility': 10000, 'wind': {'speed': 14.47, 'deg': 238, 'gust': 18.3}, 'clouds': {'all': 89}, 'dt': 1665022261, 'sys': {'country': 'AU', 'sunrise': 1665006571, 'sunset': 1665051846}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# Processing Record 6 of Set 1 | whyalla
# {'coord': {'lon': 137.5833, 'lat': -33.0333}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 78.69, 'feels_like': 77.63, 'temp_min': 78.69, 'temp_max': 78.69, 'pressure': 1011, 'humidity': 29}, 'visibility': 10000, 'wind': {'speed': 17.27, 'deg': 330, 'gust': 28.77}, 'clouds': {'all': 75}, 'dt': 1665022261, 'sys': {'type': 1, 'id': 9613, 'country': 'AU', 'sunrise': 1665001256, 'sunset': 1665046483}, 'timezone': 37800, 'id': 2058430, 'name': 'Whyalla', 'cod': 200}
# Processing Record 7 of Set 1 | bodden town
# {'coord': {'lon': -81.25, 'lat': 19.2833}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 81.82, 'feels_like': 87.19, 'temp_min': 80.98, 'temp_max': 84.2, 'pressure': 1013, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 40}, 'clouds': {'all': 75}, 'dt': 1665022163, 'sys': {'type': 2, 'id': 2012523, 'country': 'KY', 'sunrise': 1664968588, 'sunset': 1665011405}, 'timezone': -18000, 'id': 3580733, 'name': 'Bodden Town', 'cod': 200}
# Processing Record 8 of Set 1 | namibe
# {'coord': {'lon': 12.1522, 'lat': -15.1961}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 62.01, 'feels_like': 62.13, 'temp_min': 62.01, 'temp_max': 62.01, 'pressure': 1012, 'humidity': 90, 'sea_level': 1012, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 7.61, 'deg': 216, 'gust': 7.63}, 'clouds': {'all': 50}, 'dt': 1665022262, 'sys': {'country': 'AO', 'sunrise': 1665031827, 'sunset': 1665076106}, 'timezone': 3600, 'id': 3347019, 'name': 'Mossamedes', 'cod': 200}
# Processing Record 9 of Set 1 | qaanaaq
# {'coord': {'lon': -69.3632, 'lat': 77.484}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 5.25, 'feels_like': -7.35, 'temp_min': 5.25, 'temp_max': 5.25, 'pressure': 999, 'humidity': 70, 'sea_level': 999, 'grnd_level': 995}, 'visibility': 10000, 'wind': {'speed': 7.92, 'deg': 10, 'gust': 7.38}, 'clouds': {'all': 35}, 'dt': 1665022262, 'sys': {'country': 'GL', 'sunrise': 1664969877, 'sunset': 1665004412}, 'timezone': -10800, 'id': 3831208, 'name': 'Qaanaaq', 'cod': 200}
# Processing Record 10 of Set 1 | coquimbo
# {'coord': {'lon': -71.3436, 'lat': -29.9533}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 55.13, 'feels_like': 54.77, 'temp_min': 55.13, 'temp_max': 55.13, 'pressure': 1023, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 2.3, 'deg': 0}, 'clouds': {'all': 0}, 'dt': 1665022071, 'sys': {'type': 1, 'id': 8514, 'country': 'CL', 'sunrise': 1664965125, 'sunset': 1665010114}, 'timezone': -10800, 'id': 3893629, 'name': 'Coquimbo', 'cod': 200}
# Processing Record 11 of Set 1 | alihe
# {'coord': {'lon': 123.7167, 'lat': 50.5667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 39.38, 'feels_like': 34.03, 'temp_min': 39.38, 'temp_max': 39.38, 'pressure': 1021, 'humidity': 29, 'sea_level': 1021, 'grnd_level': 970}, 'visibility': 10000, 'wind': {'speed': 7.63, 'deg': 298, 'gust': 11.54}, 'clouds': {'all': 0}, 'dt': 1665022262, 'sys': {'country': 'CN', 'sunrise': 1665006735, 'sunset': 1665047659}, 'timezone': 28800, 'id': 2038665, 'name': 'Alihe', 'cod': 200}
# Processing Record 12 of Set 1 | hilo
# {'coord': {'lon': -155.09, 'lat': 19.7297}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 78.87, 'feels_like': 78.87, 'temp_min': 77.11, 'temp_max': 82.26, 'pressure': 1013, 'humidity': 84}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 80}, 'clouds': {'all': 75}, 'dt': 1665022263, 'sys': {'type': 1, 'id': 7881, 'country': 'US', 'sunrise': 1664986323, 'sunset': 1665029106}, 'timezone': -36000, 'id': 5855927, 'name': 'Hilo', 'cod': 200}
# Processing Record 13 of Set 1 | ushuaia
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 38.86, 'feels_like': 28.54, 'temp_min': 38.86, 'temp_max': 38.86, 'pressure': 993, 'humidity': 93}, 'visibility': 8000, 'wind': {'speed': 21.85, 'deg': 250}, 'clouds': {'all': 100}, 'dt': 1665022263, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1664963305, 'sunset': 1665010474}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# Processing Record 14 of Set 1 | pontianak
# {'coord': {'lon': 109.3333, 'lat': -0.0333}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 76.98, 'feels_like': 78.8, 'temp_min': 76.98, 'temp_max': 76.98, 'pressure': 1011, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 90}, 'clouds': {'all': 75}, 'dt': 1665022264, 'sys': {'type': 2, 'id': 2021448, 'country': 'ID', 'sunrise': 1665008847, 'sunset': 1665052449}, 'timezone': 25200, 'id': 1630789, 'name': 'Pontianak', 'cod': 200}
# Processing Record 15 of Set 1 | ternate
# {'coord': {'lon': 127.4, 'lat': 0.8}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 85.57, 'feels_like': 92.07, 'temp_min': 85.57, 'temp_max': 85.57, 'pressure': 1010, 'humidity': 65, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 2.01, 'deg': 172, 'gust': 3.4}, 'clouds': {'all': 100}, 'dt': 1665022264, 'sys': {'country': 'ID', 'sunrise': 1665004529, 'sunset': 1665048096}, 'timezone': 32400, 'id': 1624041, 'name': 'Ternate', 'cod': 200}
# Processing Record 16 of Set 1 | suslovo
# {'coord': {'lon': 88.1167, 'lat': 56.2167}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 34.16, 'feels_like': 28.51, 'temp_min': 34.16, 'temp_max': 34.16, 'pressure': 1028, 'humidity': 99, 'sea_level': 1028, 'grnd_level': 1004}, 'visibility': 23, 'wind': {'speed': 6.4, 'deg': 271, 'gust': 15.82}, 'snow': {'1h': 0.35}, 'clouds': {'all': 100}, 'dt': 1665022264, 'sys': {'country': 'RU', 'sunrise': 1665015580, 'sunset': 1665055898}, 'timezone': 25200, 'id': 1490591, 'name': 'Suslovo', 'cod': 200}
# Processing Record 17 of Set 1 | xadani
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 18 of Set 1 | sinnamary
# {'coord': {'lon': -52.95, 'lat': 5.3833}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 78.57, 'feels_like': 80.2, 'temp_min': 78.57, 'temp_max': 78.57, 'pressure': 1012, 'humidity': 87, 'sea_level': 1012, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 9.62, 'deg': 92, 'gust': 15.12}, 'clouds': {'all': 3}, 'dt': 1665022265, 'sys': {'country': 'GF', 'sunrise': 1664961513, 'sunset': 1665004899}, 'timezone': -10800, 'id': 3380290, 'name': 'Sinnamary', 'cod': 200}
# Processing Record 19 of Set 1 | geraldton
# {'coord': {'lon': 114.6, 'lat': -28.7667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 64.81, 'feels_like': 63.1, 'temp_min': 64.81, 'temp_max': 64.81, 'pressure': 1023, 'humidity': 45}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 120}, 'clouds': {'all': 100}, 'dt': 1665022073, 'sys': {'type': 1, 'id': 9522, 'country': 'AU', 'sunrise': 1665006899, 'sunset': 1665051870}, 'timezone': 28800, 'id': 2070998, 'name': 'Geraldton', 'cod': 200}
# Processing Record 20 of Set 1 | fortuna
# {'coord': {'lon': -124.1573, 'lat': 40.5982}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 58.86, 'feels_like': 58.44, 'temp_min': 57.97, 'temp_max': 59.34, 'pressure': 1017, 'humidity': 85}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 332, 'gust': 4}, 'clouds': {'all': 47}, 'dt': 1665022265, 'sys': {'type': 2, 'id': 2040243, 'country': 'US', 'sunrise': 1664979428, 'sunset': 1665021157}, 'timezone': -25200, 'id': 5563839, 'name': 'Fortuna', 'cod': 200}
# Processing Record 21 of Set 1 | simoes
# {'coord': {'lon': -40.8178, 'lat': -7.5989}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 78.31, 'feels_like': 77.25, 'temp_min': 78.31, 'temp_max': 78.31, 'pressure': 1012, 'humidity': 30, 'sea_level': 1012, 'grnd_level': 962}, 'visibility': 10000, 'wind': {'speed': 9.78, 'deg': 91, 'gust': 27.89}, 'clouds': {'all': 87}, 'dt': 1665022266, 'sys': {'country': 'BR', 'sunrise': 1664958341, 'sunset': 1665002249}, 'timezone': -10800, 'id': 3387625, 'name': 'Simões', 'cod': 200}
# Processing Record 22 of Set 1 | port alfred
# {'coord': {'lon': 26.891, 'lat': -33.5906}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 57.18, 'feels_like': 57.02, 'temp_min': 57.18, 'temp_max': 57.18, 'pressure': 1013, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 266, 'gust': 4}, 'clouds': {'all': 66}, 'dt': 1665021858, 'sys': {'type': 2, 'id': 2072861, 'country': 'ZA', 'sunrise': 1665027779, 'sunset': 1665073081}, 'timezone': 7200, 'id': 964432, 'name': 'Port Alfred', 'cod': 200}
# Processing Record 23 of Set 1 | rikitea
# {'coord': {'lon': -134.9692, 'lat': -23.1203}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 69.94, 'feels_like': 69.4, 'temp_min': 69.94, 'temp_max': 69.94, 'pressure': 1022, 'humidity': 59, 'sea_level': 1022, 'grnd_level': 1019}, 'visibility': 10000, 'wind': {'speed': 20.24, 'deg': 121, 'gust': 19.73}, 'clouds': {'all': 71}, 'dt': 1665021674, 'sys': {'country': 'PF', 'sunrise': 1664980570, 'sunset': 1665025203}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# Processing Record 24 of Set 1 | mataura
# {'coord': {'lon': 168.8643, 'lat': -46.1927}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 47.48, 'feels_like': 42.69, 'temp_min': 47.48, 'temp_max': 47.48, 'pressure': 1020, 'humidity': 91, 'sea_level': 1020, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 10.65, 'deg': 231, 'gust': 25.75}, 'clouds': {'all': 73}, 'dt': 1665021775, 'sys': {'type': 2, 'id': 2008959, 'country': 'NZ', 'sunrise': 1664993239, 'sunset': 1665039488}, 'timezone': 46800, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# Processing Record 25 of Set 1 | saskylakh
# {'coord': {'lon': 114.0833, 'lat': 71.9167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 10.35, 'feels_like': 1.02, 'temp_min': 10.35, 'temp_max': 10.35, 'pressure': 1022, 'humidity': 96, 'sea_level': 1022, 'grnd_level': 1021}, 'visibility': 10000, 'wind': {'speed': 5.5, 'deg': 268, 'gust': 13.31}, 'clouds': {'all': 94}, 'dt': 1665022266, 'sys': {'country': 'RU', 'sunrise': 1665010953, 'sunset': 1665048064}, 'timezone': 32400, 'id': 2017155, 'name': 'Saskylakh', 'cod': 200}
# Processing Record 26 of Set 1 | atuona
# {'coord': {'lon': -139.0333, 'lat': -9.8}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 76.91, 'feels_like': 77.92, 'temp_min': 76.91, 'temp_max': 76.91, 'pressure': 1012, 'humidity': 77, 'sea_level': 1012, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 18.14, 'deg': 115, 'gust': 19.17}, 'clouds': {'all': 1}, 'dt': 1665021784, 'sys': {'country': 'PF', 'sunrise': 1664981857, 'sunset': 1665025867}, 'timezone': -34200, 'id': 4020109, 'name': 'Atuona', 'cod': 200}
# Processing Record 27 of Set 1 | ola
# {'coord': {'lon': 151.2833, 'lat': 59.5833}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 32.14, 'feels_like': 26.38, 'temp_min': 32.14, 'temp_max': 32.14, 'pressure': 994, 'humidity': 46, 'sea_level': 994, 'grnd_level': 993}, 'visibility': 10000, 'wind': {'speed': 6.02, 'deg': 312, 'gust': 7.54}, 'clouds': {'all': 63}, 'dt': 1665022267, 'sys': {'type': 2, 'id': 48852, 'country': 'RU', 'sunrise': 1665000612, 'sunset': 1665040552}, 'timezone': 39600, 'id': 2122574, 'name': 'Ola', 'cod': 200}
# Processing Record 28 of Set 1 | naze
# {'coord': {'lon': 129.4833, 'lat': 28.3667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 76.87, 'feels_like': 77.5, 'temp_min': 76.87, 'temp_max': 76.87, 'pressure': 1017, 'humidity': 69, 'sea_level': 1017, 'grnd_level': 990}, 'visibility': 10000, 'wind': {'speed': 8.66, 'deg': 4, 'gust': 8.84}, 'clouds': {'all': 77}, 'dt': 1665022267, 'sys': {'country': 'JP', 'sunrise': 1665004630, 'sunset': 1665046996}, 'timezone': 32400, 'id': 1855540, 'name': 'Naze', 'cod': 200}
# Processing Record 29 of Set 1 | husavik
# {'coord': {'lon': -17.3389, 'lat': 66.0449}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 36.14, 'feels_like': 24.21, 'temp_min': 36.14, 'temp_max': 36.14, 'pressure': 980, 'humidity': 98, 'sea_level': 980, 'grnd_level': 979}, 'visibility': 119, 'wind': {'speed': 25.12, 'deg': 290, 'gust': 38.63}, 'clouds': {'all': 100}, 'dt': 1665022268, 'sys': {'country': 'IS', 'sunrise': 1665041730, 'sunset': 1665080356}, 'timezone': 0, 'id': 2629833, 'name': 'Husavik', 'cod': 200}
# Processing Record 30 of Set 1 | guymon
# {'coord': {'lon': -101.4816, 'lat': 36.6828}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 62.6, 'feels_like': 62.19, 'temp_min': 62.6, 'temp_max': 62.6, 'pressure': 1024, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 280}, 'clouds': {'all': 100}, 'dt': 1665022257, 'sys': {'type': 1, 'id': 4282, 'country': 'US', 'sunrise': 1664973865, 'sunset': 1665015837}, 'timezone': -18000, 'id': 5515743, 'name': 'Guymon', 'cod': 200}
# Processing Record 31 of Set 1 | bambous virieux
# {'coord': {'lon': 57.7575, 'lat': -20.3428}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 71.85, 'feels_like': 72.41, 'temp_min': 68.22, 'temp_max': 71.85, 'pressure': 1021, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 130}, 'clouds': {'all': 75}, 'dt': 1665022268, 'sys': {'type': 1, 'id': 2061, 'country': 'MU', 'sunrise': 1665020761, 'sunset': 1665065286}, 'timezone': 14400, 'id': 1106677, 'name': 'Bambous Virieux', 'cod': 200}
# Processing Record 32 of Set 1 | natal
# {'coord': {'lon': -35.2094, 'lat': -5.795}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 75.85, 'feels_like': 77.56, 'temp_min': 75.85, 'temp_max': 75.85, 'pressure': 1014, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 2.3, 'deg': 180}, 'clouds': {'all': 75}, 'dt': 1665022269, 'sys': {'type': 1, 'id': 8452, 'country': 'BR', 'sunrise': 1664957032, 'sunset': 1665000866}, 'timezone': -10800, 'id': 3394023, 'name': 'Natal', 'cod': 200}
# Processing Record 33 of Set 1 | mar del plata
# {'coord': {'lon': -57.5575, 'lat': -38.0023}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 59.09, 'feels_like': 58.78, 'temp_min': 57.94, 'temp_max': 59.09, 'pressure': 1016, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 315, 'gust': 7}, 'clouds': {'all': 100}, 'dt': 1665021846, 'sys': {'type': 2, 'id': 268283, 'country': 'AR', 'sunrise': 1664961560, 'sunset': 1665007064}, 'timezone': -10800, 'id': 3430863, 'name': 'Mar del Plata', 'cod': 200}
# Processing Record 34 of Set 1 | punta arenas
# {'coord': {'lon': -70.9167, 'lat': -53.15}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 42.91, 'feels_like': 35.56, 'temp_min': 42.12, 'temp_max': 42.91, 'pressure': 995, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 14.97, 'deg': 260}, 'clouds': {'all': 0}, 'dt': 1665022175, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1664964042, 'sunset': 1665010992}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# Processing Record 35 of Set 1 | taolanaro
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 36 of Set 1 | merrill
# {'coord': {'lon': -89.6835, 'lat': 45.1805}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 56.89, 'feels_like': 56.19, 'temp_min': 54.68, 'temp_max': 61.57, 'pressure': 1015, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 260}, 'clouds': {'all': 75}, 'dt': 1665022270, 'sys': {'type': 1, 'id': 5715, 'country': 'US', 'sunrise': 1664971300, 'sunset': 1665012740}, 'timezone': -18000, 'id': 5262680, 'name': 'Merrill', 'cod': 200}
# Processing Record 37 of Set 1 | lasa
# {'coord': {'lon': 10.7002, 'lat': 46.6166}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 47.35, 'feels_like': 45.72, 'temp_min': 47.35, 'temp_max': 47.35, 'pressure': 1029, 'humidity': 78, 'sea_level': 1029, 'grnd_level': 928}, 'visibility': 10000, 'wind': {'speed': 4.12, 'deg': 335, 'gust': 4.5}, 'clouds': {'all': 9}, 'dt': 1665022270, 'sys': {'type': 2, 'id': 2002891, 'country': 'IT', 'sunrise': 1665033719, 'sunset': 1665074911}, 'timezone': 7200, 'id': 3175096, 'name': 'Laas', 'cod': 200}
# Processing Record 38 of Set 1 | hermanus
# {'coord': {'lon': 19.2345, 'lat': -34.4187}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 45.81, 'feels_like': 39.97, 'temp_min': 45.81, 'temp_max': 45.81, 'pressure': 1016, 'humidity': 82, 'sea_level': 1016, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 12.57, 'deg': 316, 'gust': 19.15}, 'clouds': {'all': 3}, 'dt': 1665021850, 'sys': {'type': 2, 'id': 2006131, 'country': 'ZA', 'sunrise': 1665029587, 'sunset': 1665074947}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# Processing Record 39 of Set 1 | gao
# {'coord': {'lon': 1.637, 'lat': 16.6362}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 89.06, 'feels_like': 85.17, 'temp_min': 89.06, 'temp_max': 89.06, 'pressure': 1009, 'humidity': 15, 'sea_level': 1009, 'grnd_level': 966}, 'visibility': 10000, 'wind': {'speed': 9.46, 'deg': 60, 'gust': 13.15}, 'clouds': {'all': 93}, 'dt': 1665022270, 'sys': {'country': 'ML', 'sunrise': 1665035047, 'sunset': 1665077932}, 'timezone': 0, 'id': 2457161, 'name': 'Gao', 'cod': 200}
# Processing Record 40 of Set 1 | tuktoyaktuk
# {'coord': {'lon': -133.0374, 'lat': 69.4541}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 33.8, 'feels_like': 23.9, 'temp_min': 33.8, 'temp_max': 33.8, 'pressure': 1012, 'humidity': 93}, 'visibility': 8047, 'wind': {'speed': 14.97, 'deg': 280}, 'clouds': {'all': 100}, 'dt': 1665022271, 'sys': {'type': 1, 'id': 942, 'country': 'CA', 'sunrise': 1664983382, 'sunset': 1665021464}, 'timezone': -21600, 'id': 6170031, 'name': 'Tuktoyaktuk', 'cod': 200}
# Processing Record 41 of Set 1 | nantucket
# {'coord': {'lon': -70.0995, 'lat': 41.2835}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 59.74, 'feels_like': 60.03, 'temp_min': 58.14, 'temp_max': 60.94, 'pressure': 1010, 'humidity': 98}, 'visibility': 10000, 'wind': {'speed': 14.97, 'deg': 360}, 'clouds': {'all': 100}, 'dt': 1665022271, 'sys': {'type': 1, 'id': 3218, 'country': 'US', 'sunrise': 1664966466, 'sunset': 1665008176}, 'timezone': -14400, 'id': 4944903, 'name': 'Nantucket', 'cod': 200}
# Processing Record 42 of Set 1 | carnarvon
# {'coord': {'lon': 113.6333, 'lat': -24.8667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 68.07, 'feels_like': 66.18, 'temp_min': 68.07, 'temp_max': 68.07, 'pressure': 1020, 'humidity': 34}, 'visibility': 10000, 'wind': {'speed': 25.32, 'deg': 140, 'gust': 36.82}, 'clouds': {'all': 0}, 'dt': 1665021857, 'sys': {'type': 1, 'id': 9505, 'country': 'AU', 'sunrise': 1665007241, 'sunset': 1665051992}, 'timezone': 28800, 'id': 2074865, 'name': 'Carnarvon', 'cod': 200}
# Processing Record 43 of Set 1 | beringovskiy
# {'coord': {'lon': 179.3167, 'lat': 63.05}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 42.69, 'feels_like': 32.23, 'temp_min': 42.69, 'temp_max': 42.69, 'pressure': 982, 'humidity': 79, 'sea_level': 982, 'grnd_level': 979}, 'visibility': 10000, 'wind': {'speed': 29.28, 'deg': 240, 'gust': 39.66}, 'clouds': {'all': 40}, 'dt': 1665022224, 'sys': {'country': 'RU', 'sunrise': 1664994140, 'sunset': 1665033571}, 'timezone': 43200, 'id': 2126710, 'name': 'Beringovskiy', 'cod': 200}
# Processing Record 44 of Set 1 | tucuma
# {'coord': {'lon': -50.05, 'lat': -0.1833}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 78.44, 'feels_like': 79.61, 'temp_min': 78.44, 'temp_max': 78.44, 'pressure': 1011, 'humidity': 77, 'sea_level': 1011, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 8.37, 'deg': 52, 'gust': 17.65}, 'clouds': {'all': 38}, 'dt': 1665022272, 'sys': {'country': 'BR', 'sunrise': 1664960707, 'sunset': 1665004314}, 'timezone': -10800, 'id': 3385980, 'name': 'Tucumã', 'cod': 200}
# Processing Record 45 of Set 1 | aden
# {'coord': {'lon': 45.0367, 'lat': 12.7794}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 85.35, 'feels_like': 93.52, 'temp_min': 85.35, 'temp_max': 85.35, 'pressure': 1009, 'humidity': 70, 'sea_level': 1009, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 0.92, 'deg': 32, 'gust': 1.36}, 'clouds': {'all': 86}, 'dt': 1665022272, 'sys': {'country': 'YE', 'sunrise': 1665024546, 'sunset': 1665067606}, 'timezone': 10800, 'id': 415189, 'name': 'Aden', 'cod': 200}
# Processing Record 46 of Set 1 | cape town
# {'coord': {'lon': 18.4232, 'lat': -33.9258}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 55.8, 'feels_like': 54.7, 'temp_min': 50.11, 'temp_max': 61.38, 'pressure': 1017, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 180, 'gust': 5.99}, 'clouds': {'all': 71}, 'dt': 1665022146, 'sys': {'type': 2, 'id': 2073005, 'country': 'ZA', 'sunrise': 1665029798, 'sunset': 1665075125}, 'timezone': 7200, 'id': 3369157, 'name': 'Cape Town', 'cod': 200}
# Processing Record 47 of Set 1 | barrow
# {'coord': {'lon': -156.7887, 'lat': 71.2906}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 33.82, 'feels_like': 27.03, 'temp_min': 33.82, 'temp_max': 33.82, 'pressure': 1010, 'humidity': 80}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 150}, 'clouds': {'all': 0}, 'dt': 1665021781, 'sys': {'type': 1, 'id': 7649, 'country': 'US', 'sunrise': 1664989384, 'sunset': 1665026860}, 'timezone': -28800, 'id': 5880054, 'name': 'Barrow', 'cod': 200}
# Processing Record 48 of Set 1 | albany
# {'coord': {'lon': -73.9662, 'lat': 42.6001}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 49.69, 'feels_like': 48.42, 'temp_min': 46.29, 'temp_max': 52.56, 'pressure': 1014, 'humidity': 91}, 'visibility': 10000, 'wind': {'speed': 4.14, 'deg': 299, 'gust': 4.27}, 'clouds': {'all': 12}, 'dt': 1665021604, 'sys': {'type': 2, 'id': 19530, 'country': 'US', 'sunrise': 1664967437, 'sunset': 1665009061}, 'timezone': -14400, 'id': 5106841, 'name': 'Albany', 'cod': 200}
# Processing Record 49 of Set 1 | bredasdorp
# {'coord': {'lon': 20.0403, 'lat': -34.5322}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 48.69, 'feels_like': 45.46, 'temp_min': 48.69, 'temp_max': 48.69, 'pressure': 1016, 'humidity': 91, 'sea_level': 1016, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 7.29, 'deg': 315, 'gust': 9.28}, 'clouds': {'all': 1}, 'dt': 1665022273, 'sys': {'country': 'ZA', 'sunrise': 1665029390, 'sunset': 1665074758}, 'timezone': 7200, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}
# Processing Record 50 of Set 1 | bluff
# {'coord': {'lon': 168.3333, 'lat': -46.6}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 47.8, 'feels_like': 40.41, 'temp_min': 47.8, 'temp_max': 47.8, 'pressure': 1021, 'humidity': 61, 'sea_level': 1021, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 21.59, 'deg': 222, 'gust': 28.14}, 'clouds': {'all': 95}, 'dt': 1665021701, 'sys': {'type': 2, 'id': 2008959, 'country': 'NZ', 'sunrise': 1664993346, 'sunset': 1665039636}, 'timezone': 46800, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# Processing Record 1 of Set 2 | mys shmidta
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 2 of Set 2 | kahului
# {'coord': {'lon': -156.47, 'lat': 20.8947}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 82.22, 'feels_like': 88.05, 'temp_min': 78.84, 'temp_max': 84.97, 'pressure': 1013, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 19.57, 'deg': 30}, 'rain': {'1h': 0.25}, 'clouds': {'all': 40}, 'dt': 1665022333, 'sys': {'type': 1, 'id': 7879, 'country': 'US', 'sunrise': 1664986679, 'sunset': 1665029412}, 'timezone': -36000, 'id': 5847411, 'name': 'Kahului', 'cod': 200}
# Processing Record 3 of Set 2 | nikolskoye
# {'coord': {'lon': 30.7861, 'lat': 59.7035}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 49.68, 'feels_like': 46.36, 'temp_min': 46.78, 'temp_max': 49.91, 'pressure': 1009, 'humidity': 98, 'sea_level': 1009, 'grnd_level': 1005}, 'visibility': 7179, 'wind': {'speed': 8.01, 'deg': 177, 'gust': 21.9}, 'clouds': {'all': 99}, 'dt': 1665022334, 'sys': {'type': 2, 'id': 47750, 'country': 'RU', 'sunrise': 1665029587, 'sunset': 1665069403}, 'timezone': 10800, 'id': 546105, 'name': 'Nikolskoye', 'cod': 200}
# Processing Record 4 of Set 2 | wulanhaote
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 5 of Set 2 | sabha
# {'coord': {'lon': 14.4283, 'lat': 27.0377}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 69.13, 'feels_like': 67.77, 'temp_min': 69.13, 'temp_max': 69.13, 'pressure': 1020, 'humidity': 43, 'sea_level': 1020, 'grnd_level': 971}, 'visibility': 10000, 'wind': {'speed': 10.78, 'deg': 50, 'gust': 20.45}, 'clouds': {'all': 0}, 'dt': 1665022334, 'sys': {'country': 'LY', 'sunrise': 1665032219, 'sunset': 1665074621}, 'timezone': 7200, 'id': 2212775, 'name': 'Sabha', 'cod': 200}
# Processing Record 6 of Set 2 | mount pleasant
# {'coord': {'lon': -79.8626, 'lat': 32.7941}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 58.8, 'feels_like': 58.42, 'temp_min': 55.62, 'temp_max': 62.01, 'pressure': 1018, 'humidity': 86}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 0}, 'dt': 1665022335, 'sys': {'type': 2, 'id': 2008639, 'country': 'US', 'sunrise': 1664968569, 'sunset': 1665010758}, 'timezone': -14400, 'id': 4588165, 'name': 'Mt. Pleasant', 'cod': 200}
# Processing Record 7 of Set 2 | grand river south east
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 8 of Set 2 | saleaula
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 9 of Set 2 | sadasivpet
# {'coord': {'lon': 77.9503, 'lat': 17.6212}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 71.69, 'feels_like': 72.88, 'temp_min': 71.69, 'temp_max': 71.69, 'pressure': 1008, 'humidity': 92, 'sea_level': 1008, 'grnd_level': 947}, 'visibility': 9765, 'wind': {'speed': 2.24, 'deg': 30, 'gust': 4.29}, 'clouds': {'all': 100}, 'dt': 1665022335, 'sys': {'country': 'IN', 'sunrise': 1665016751, 'sunset': 1665059605}, 'timezone': 19800, 'id': 1257431, 'name': 'Sadasivpet', 'cod': 200}
# Processing Record 10 of Set 2 | illoqqortoormiut
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 11 of Set 2 | taltal
# {'coord': {'lon': -70.4833, 'lat': -25.4}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 60.26, 'feels_like': 58.77, 'temp_min': 60.26, 'temp_max': 60.26, 'pressure': 1019, 'humidity': 59, 'sea_level': 1019, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 8.41, 'deg': 185, 'gust': 9.53}, 'clouds': {'all': 0}, 'dt': 1665022220, 'sys': {'country': 'CL', 'sunrise': 1664965045, 'sunset': 1665009781}, 'timezone': -10800, 'id': 3870243, 'name': 'Taltal', 'cod': 200}
# Processing Record 12 of Set 2 | lagoa
# {'coord': {'lon': -27.9833, 'lat': 39.05}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 69.03, 'feels_like': 69.67, 'temp_min': 69.03, 'temp_max': 69.03, 'pressure': 1028, 'humidity': 86, 'sea_level': 1028, 'grnd_level': 1019}, 'visibility': 10000, 'wind': {'speed': 17.58, 'deg': 112, 'gust': 17.94}, 'rain': {'1h': 0.75}, 'clouds': {'all': 97}, 'dt': 1665022336, 'sys': {'country': 'PT', 'sunrise': 1665042740, 'sunset': 1665084454}, 'timezone': 0, 'id': 3372964, 'name': 'Lagoa', 'cod': 200}
# Processing Record 13 of Set 2 | warqla
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 14 of Set 2 | klaksvik
# {'coord': {'lon': -6.589, 'lat': 62.2266}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 49.12, 'feels_like': 41.22, 'temp_min': 49.12, 'temp_max': 49.12, 'pressure': 987, 'humidity': 80, 'sea_level': 987, 'grnd_level': 985}, 'visibility': 10000, 'wind': {'speed': 27.42, 'deg': 245, 'gust': 34.61}, 'clouds': {'all': 78}, 'dt': 1665022337, 'sys': {'type': 1, 'id': 1596, 'country': 'FO', 'sunrise': 1665038771, 'sunset': 1665078156}, 'timezone': 3600, 'id': 2618795, 'name': 'Klaksvík', 'cod': 200}
# Processing Record 15 of Set 2 | tasiilaq
# {'coord': {'lon': -37.6368, 'lat': 65.6145}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 32.16, 'feels_like': 26.26, 'temp_min': 32.16, 'temp_max': 32.16, 'pressure': 987, 'humidity': 50, 'sea_level': 987, 'grnd_level': 983}, 'visibility': 10000, 'wind': {'speed': 6.22, 'deg': 1, 'gust': 5.88}, 'clouds': {'all': 86}, 'dt': 1665022337, 'sys': {'type': 1, 'id': 81, 'country': 'GL', 'sunrise': 1665046564, 'sunset': 1665085262}, 'timezone': -7200, 'id': 3424607, 'name': 'Tasiilaq', 'cod': 200}
# Processing Record 16 of Set 2 | tabas
# {'coord': {'lon': 56.9244, 'lat': 33.5959}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 70.29, 'feels_like': 68, 'temp_min': 70.29, 'temp_max': 70.29, 'pressure': 1016, 'humidity': 21, 'sea_level': 1016, 'grnd_level': 941}, 'visibility': 10000, 'wind': {'speed': 1.95, 'deg': 96, 'gust': 4.23}, 'clouds': {'all': 0}, 'dt': 1665022169, 'sys': {'country': 'IR', 'sunrise': 1665022188, 'sunset': 1665064259}, 'timezone': 12600, 'id': 113659, 'name': 'Tabas', 'cod': 200}
# Processing Record 17 of Set 2 | castro
# {'coord': {'lon': -50.0119, 'lat': -24.7911}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 59.68, 'feels_like': 59.86, 'temp_min': 59.68, 'temp_max': 59.68, 'pressure': 1016, 'humidity': 96, 'sea_level': 1016, 'grnd_level': 904}, 'visibility': 10000, 'wind': {'speed': 5.95, 'deg': 70, 'gust': 14.54}, 'rain': {'1h': 1.06}, 'clouds': {'all': 100}, 'dt': 1665021775, 'sys': {'country': 'BR', 'sunrise': 1664960151, 'sunset': 1665004851}, 'timezone': -10800, 'id': 3466704, 'name': 'Castro', 'cod': 200}
# Processing Record 18 of Set 2 | augusto correa
# {'coord': {'lon': -46.635, 'lat': -1.0217}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 78.98, 'feels_like': 78.98, 'temp_min': 78.98, 'temp_max': 78.98, 'pressure': 1011, 'humidity': 77, 'sea_level': 1011, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 6.82, 'deg': 66, 'gust': 18.59}, 'clouds': {'all': 0}, 'dt': 1665022338, 'sys': {'country': 'BR', 'sunrise': 1664959870, 'sunset': 1665003511}, 'timezone': -10800, 'id': 3406961, 'name': 'Augusto Corrêa', 'cod': 200}
# Processing Record 19 of Set 2 | nara
# {'coord': {'lon': 135.8049, 'lat': 34.6851}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 67.82, 'feels_like': 66, 'temp_min': 60.69, 'temp_max': 68.5, 'pressure': 1019, 'humidity': 36, 'sea_level': 1019, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 6.33, 'deg': 357, 'gust': 7.83}, 'clouds': {'all': 100}, 'dt': 1665022288, 'sys': {'type': 2, 'id': 20513, 'country': 'JP', 'sunrise': 1665003277, 'sunset': 1665045315}, 'timezone': 32400, 'id': 1855612, 'name': 'Nara', 'cod': 200}
# Processing Record 20 of Set 2 | tuatapere
# {'coord': {'lon': 167.6833, 'lat': -46.1333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 45.73, 'feels_like': 39.2, 'temp_min': 45.73, 'temp_max': 45.73, 'pressure': 1022, 'humidity': 75, 'sea_level': 1022, 'grnd_level': 1019}, 'visibility': 10000, 'wind': {'speed': 14.9, 'deg': 223, 'gust': 25.37}, 'clouds': {'all': 96}, 'dt': 1665022293, 'sys': {'country': 'NZ', 'sunrise': 1664993525, 'sunset': 1665039769}, 'timezone': 46800, 'id': 2180815, 'name': 'Tuatapere', 'cod': 200}
# Processing Record 21 of Set 2 | jamestown
# {'coord': {'lon': -79.2353, 'lat': 42.097}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 50.09, 'feels_like': 48, 'temp_min': 46.94, 'temp_max': 52.72, 'pressure': 1017, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 115, 'gust': 1.01}, 'clouds': {'all': 28}, 'dt': 1665021614, 'sys': {'type': 2, 'id': 2008933, 'country': 'US', 'sunrise': 1664968686, 'sunset': 1665010340}, 'timezone': -14400, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# Processing Record 22 of Set 2 | bud
# {'coord': {'lon': -86.1758, 'lat': 39.447}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 53.94, 'feels_like': 52.75, 'temp_min': 49.42, 'temp_max': 57.9, 'pressure': 1019, 'humidity': 79, 'sea_level': 1019, 'grnd_level': 989}, 'visibility': 10000, 'wind': {'speed': 4.32, 'deg': 256, 'gust': 4.34}, 'clouds': {'all': 26}, 'dt': 1665022338, 'sys': {'type': 2, 'id': 2006000, 'country': 'US', 'sunrise': 1664970270, 'sunset': 1665012087}, 'timezone': -14400, 'id': 4255151, 'name': 'Bud', 'cod': 200}
# Processing Record 23 of Set 2 | vardo
# {'coord': {'lon': 31.1107, 'lat': 70.3705}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 44.58, 'feels_like': 38.05, 'temp_min': 44.58, 'temp_max': 44.58, 'pressure': 997, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 180}, 'clouds': {'all': 100}, 'dt': 1665022339, 'sys': {'type': 1, 'id': 1666, 'country': 'NO', 'sunrise': 1665030656, 'sunset': 1665068178}, 'timezone': 7200, 'id': 777019, 'name': 'Vardø', 'cod': 200}
# Processing Record 24 of Set 2 | cherskiy
# {'coord': {'lon': 161.3, 'lat': 68.75}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 29.88, 'feels_like': 20.89, 'temp_min': 29.88, 'temp_max': 29.88, 'pressure': 975, 'humidity': 94, 'sea_level': 975, 'grnd_level': 975}, 'visibility': 213, 'wind': {'speed': 10.38, 'deg': 29, 'gust': 16.69}, 'snow': {'1h': 0.3}, 'clouds': {'all': 100}, 'dt': 1665021861, 'sys': {'country': 'RU', 'sunrise': 1664999086, 'sunset': 1665037271}, 'timezone': 39600, 'id': 2126199, 'name': 'Cherskiy', 'cod': 200}
# Processing Record 25 of Set 2 | kodiak
# {'coord': {'lon': -152.4072, 'lat': 57.79}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}, {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 53.11, 'feels_like': 52.21, 'temp_min': 53.11, 'temp_max': 53.11, 'pressure': 1005, 'humidity': 87}, 'visibility': 2414, 'wind': {'speed': 9.22, 'deg': 50}, 'clouds': {'all': 100}, 'dt': 1665022339, 'sys': {'type': 1, 'id': 7668, 'country': 'US', 'sunrise': 1664986959, 'sunset': 1665027182}, 'timezone': -28800, 'id': 5866583, 'name': 'Saint Paul Harbor', 'cod': 200}
# Processing Record 26 of Set 2 | alyangula
# {'coord': {'lon': 136.4192, 'lat': -13.8483}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 87.06, 'feels_like': 92.79, 'temp_min': 87.06, 'temp_max': 87.06, 'pressure': 1012, 'humidity': 59, 'sea_level': 1012, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 6.98, 'deg': 69, 'gust': 10.71}, 'clouds': {'all': 57}, 'dt': 1665022340, 'sys': {'country': 'AU', 'sunrise': 1665002049, 'sunset': 1665046248}, 'timezone': 34200, 'id': 2079582, 'name': 'Alyangula', 'cod': 200}
# Processing Record 27 of Set 2 | port lincoln
# {'coord': {'lon': 135.8667, 'lat': -34.7333}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 67.59, 'feels_like': 66.72, 'temp_min': 67.59, 'temp_max': 67.59, 'pressure': 1010, 'humidity': 57, 'sea_level': 1010, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 7.36, 'deg': 338, 'gust': 14.47}, 'rain': {'1h': 0.44}, 'clouds': {'all': 0}, 'dt': 1665022323, 'sys': {'country': 'AU', 'sunrise': 1665001611, 'sunset': 1665046951}, 'timezone': 37800, 'id': 2063036, 'name': 'Port Lincoln', 'cod': 200}
# Processing Record 28 of Set 2 | upernavik
# {'coord': {'lon': -56.1549, 'lat': 72.7868}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 19.92, 'feels_like': 13.51, 'temp_min': 19.92, 'temp_max': 19.92, 'pressure': 997, 'humidity': 89, 'sea_level': 997, 'grnd_level': 997}, 'visibility': 10000, 'wind': {'speed': 4.47, 'deg': 112, 'gust': 4.43}, 'clouds': {'all': 100}, 'dt': 1665022294, 'sys': {'country': 'GL', 'sunrise': 1665052117, 'sunset': 1665088596}, 'timezone': -7200, 'id': 3418910, 'name': 'Upernavik', 'cod': 200}
# Processing Record 29 of Set 2 | roela
# {'coord': {'lon': 26.5926, 'lat': 59.1667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 52.61, 'feels_like': 52, 'temp_min': 52.61, 'temp_max': 52.61, 'pressure': 1007, 'humidity': 94, 'sea_level': 1007, 'grnd_level': 995}, 'visibility': 10000, 'wind': {'speed': 10.8, 'deg': 209, 'gust': 27.36}, 'clouds': {'all': 100}, 'dt': 1665022341, 'sys': {'country': 'EE', 'sunrise': 1665030557, 'sunset': 1665070446}, 'timezone': 10800, 'id': 587571, 'name': 'Roela', 'cod': 200}
# Processing Record 30 of Set 2 | arraial do cabo
# {'coord': {'lon': -42.0278, 'lat': -22.9661}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 69.08, 'feels_like': 69.67, 'temp_min': 69.08, 'temp_max': 69.08, 'pressure': 1018, 'humidity': 85, 'sea_level': 1018, 'grnd_level': 1016}, 'visibility': 10000, 'wind': {'speed': 12.93, 'deg': 91, 'gust': 16.06}, 'clouds': {'all': 100}, 'dt': 1665021929, 'sys': {'country': 'BR', 'sunrise': 1664958283, 'sunset': 1665002887}, 'timezone': -10800, 'id': 3471451, 'name': 'Arraial do Cabo', 'cod': 200}
# Processing Record 31 of Set 2 | attawapiskat
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 32 of Set 2 | puri
# {'coord': {'lon': 85.85, 'lat': 19.8}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 77.52, 'feels_like': 78.64, 'temp_min': 77.52, 'temp_max': 77.52, 'pressure': 1009, 'humidity': 78, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 9.44, 'deg': 145, 'gust': 11.05}, 'clouds': {'all': 55}, 'dt': 1665022342, 'sys': {'type': 1, 'id': 9113, 'country': 'IN', 'sunrise': 1665014904, 'sunset': 1665057662}, 'timezone': 19800, 'id': 1259184, 'name': 'Puri', 'cod': 200}
# Processing Record 33 of Set 2 | kaitangata
# {'coord': {'lon': 169.8464, 'lat': -46.2817}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 42.87, 'feels_like': 34.83, 'temp_min': 42.87, 'temp_max': 42.87, 'pressure': 1019, 'humidity': 80, 'sea_level': 1019, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 17.58, 'deg': 230, 'gust': 32.12}, 'clouds': {'all': 95}, 'dt': 1665022344, 'sys': {'country': 'NZ', 'sunrise': 1664992999, 'sunset': 1665039256}, 'timezone': 46800, 'id': 2208248, 'name': 'Kaitangata', 'cod': 200}
# Processing Record 34 of Set 2 | atambua
# {'coord': {'lon': 124.8925, 'lat': -9.1061}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 84.72, 'feels_like': 87.62, 'temp_min': 84.72, 'temp_max': 84.72, 'pressure': 1011, 'humidity': 56, 'sea_level': 1011, 'grnd_level': 973}, 'visibility': 10000, 'wind': {'speed': 2.17, 'deg': 43, 'gust': 7.9}, 'clouds': {'all': 94}, 'dt': 1665022344, 'sys': {'country': 'ID', 'sunrise': 1665004921, 'sunset': 1665048908}, 'timezone': 28800, 'id': 1651103, 'name': 'Atambua', 'cod': 200}
# Processing Record 35 of Set 2 | lebu
# {'coord': {'lon': -73.65, 'lat': -37.6167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 50.88, 'feels_like': 49.95, 'temp_min': 50.88, 'temp_max': 50.88, 'pressure': 1024, 'humidity': 91, 'sea_level': 1024, 'grnd_level': 1020}, 'visibility': 10000, 'wind': {'speed': 10.92, 'deg': 347, 'gust': 18.39}, 'clouds': {'all': 100}, 'dt': 1665021822, 'sys': {'country': 'CL', 'sunrise': 1664965432, 'sunset': 1665010914}, 'timezone': -10800, 'id': 3883457, 'name': 'Lebu', 'cod': 200}
# Processing Record 36 of Set 2 | raga
# {'coord': {'lon': 25.678, 'lat': 8.4596}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 69.01, 'feels_like': 69.98, 'temp_min': 69.01, 'temp_max': 69.01, 'pressure': 1011, 'humidity': 93, 'sea_level': 1011, 'grnd_level': 949}, 'visibility': 10000, 'wind': {'speed': 1.68, 'deg': 138, 'gust': 1.88}, 'rain': {'1h': 0.19}, 'clouds': {'all': 100}, 'dt': 1665022231, 'sys': {'country': 'SS', 'sunrise': 1665029100, 'sunset': 1665072342}, 'timezone': 7200, 'id': 368246, 'name': 'Raja', 'cod': 200}
# Processing Record 37 of Set 2 | mount gambier
# {'coord': {'lon': 140.7667, 'lat': -37.8333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 60.71, 'feels_like': 60.91, 'temp_min': 60.71, 'temp_max': 60.71, 'pressure': 1011, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 14.97, 'deg': 10}, 'clouds': {'all': 100}, 'dt': 1665022301, 'sys': {'type': 1, 'id': 9560, 'country': 'AU', 'sunrise': 1665000327, 'sunset': 1665045884}, 'timezone': 37800, 'id': 2156643, 'name': 'Mount Gambier', 'cod': 200}
# Processing Record 38 of Set 2 | hobart
# ...
# Processing Record 41 of Set 15 | diu
# {'coord': {'lon': 70.9822, 'lat': 20.7141}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 77.43, 'feels_like': 78.55, 'temp_min': 77.43, 'temp_max': 77.43, 'pressure': 1007, 'humidity': 78, 'sea_level': 1007, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 12.3, 'deg': 291, 'gust': 20.2}, 'clouds': {'all': 11}, 'dt': 1665023367, 'sys': {'country': 'IN', 'sunrise': 1665018493, 'sunset': 1665061207}, 'timezone': 19800, 'id': 1272502, 'name': 'Diu', 'cod': 200}
# Processing Record 42 of Set 15 | lagunillas
# {'coord': {'lon': -71.2595, 'lat': 10.1301}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 78.78, 'feels_like': 78.78, 'temp_min': 78.78, 'temp_max': 78.78, 'pressure': 1010, 'humidity': 86, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 7.29, 'deg': 32, 'gust': 11.92}, 'rain': {'1h': 0.15}, 'clouds': {'all': 100}, 'dt': 1665023367, 'sys': {'country': 'VE', 'sunrise': 1664966002, 'sunset': 1665009197}, 'timezone': -14400, 'id': 3637623, 'name': 'Lagunillas', 'cod': 200}
# Processing Record 43 of Set 15 | goundi
# {'coord': {'lon': 17.366, 'lat': 9.3627}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 72.86, 'feels_like': 74.21, 'temp_min': 72.86, 'temp_max': 72.86, 'pressure': 1010, 'humidity': 93, 'sea_level': 1010, 'grnd_level': 967}, 'visibility': 10000, 'wind': {'speed': 3.56, 'deg': 176, 'gust': 3.74}, 'clouds': {'all': 94}, 'dt': 1665023368, 'sys': {'country': 'TD', 'sunrise': 1665031114, 'sunset': 1665074317}, 'timezone': 3600, 'id': 2431736, 'name': 'Goundi', 'cod': 200}
# Processing Record 44 of Set 15 | grindavik
# {'coord': {'lon': -22.4338, 'lat': 63.8424}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 41.47, 'feels_like': 37.67, 'temp_min': 39.15, 'temp_max': 41.47, 'pressure': 986, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 240}, 'clouds': {'all': 75}, 'dt': 1665023368, 'sys': {'type': 1, 'id': 90, 'country': 'IS', 'sunrise': 1665042727, 'sunset': 1665081804}, 'timezone': 0, 'id': 3416888, 'name': 'Grindavik', 'cod': 200}
# Processing Record 45 of Set 15 | muros
# {'coord': {'lon': -9.0603, 'lat': 42.7762}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 62.83, 'feels_like': 62.62, 'temp_min': 62.83, 'temp_max': 64.09, 'pressure': 1026, 'humidity': 81, 'sea_level': 1026, 'grnd_level': 1024}, 'visibility': 10000, 'wind': {'speed': 14.07, 'deg': 44, 'gust': 28.72}, 'clouds': {'all': 60}, 'dt': 1665023368, 'sys': {'type': 2, 'id': 72671, 'country': 'ES', 'sunrise': 1665038321, 'sunset': 1665079792}, 'timezone': 7200, 'id': 3115824, 'name': 'Muros', 'cod': 200}
# Processing Record 46 of Set 15 | banmo
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 47 of Set 15 | ballina
# {'coord': {'lon': 153.5667, 'lat': -28.8667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 60.64, 'feels_like': 60.73, 'temp_min': 60.64, 'temp_max': 60.64, 'pressure': 1023, 'humidity': 92, 'sea_level': 1023, 'grnd_level': 1022}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 263, 'gust': 1.63}, 'clouds': {'all': 100}, 'dt': 1665023369, 'sys': {'country': 'AU', 'sunrise': 1664997551, 'sunset': 1665042517}, 'timezone': 39600, 'id': 2177069, 'name': 'Ballina', 'cod': 200}
# Processing Record 48 of Set 15 | stonewall
# {'coord': {'lon': -97.3268, 'lat': 50.1344}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 42.21, 'feels_like': 33.13, 'temp_min': 41.68, 'temp_max': 43.79, 'pressure': 1027, 'humidity': 61, 'sea_level': 1027, 'grnd_level': 996}, 'visibility': 10000, 'wind': {'speed': 21.07, 'deg': 6, 'gust': 29.84}, 'clouds': {'all': 100}, 'dt': 1665023370, 'sys': {'type': 2, 'id': 2010793, 'country': 'CA', 'sunrise': 1664973330, 'sunset': 1665014378}, 'timezone': -18000, 'id': 6157355, 'name': 'Stonewall', 'cod': 200}
# Processing Record 49 of Set 15 | megion
# {'coord': {'lon': 76.1136, 'lat': 61.0296}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 30.02, 'feels_like': 25.75, 'temp_min': 30.02, 'temp_max': 30.22, 'pressure': 1030, 'humidity': 83, 'sea_level': 1030, 'grnd_level': 1025}, 'visibility': 10000, 'wind': {'speed': 4.03, 'deg': 107, 'gust': 4.05}, 'clouds': {'all': 22}, 'dt': 1665023370, 'sys': {'type': 2, 'id': 49593, 'country': 'RU', 'sunrise': 1665018790, 'sunset': 1665058448}, 'timezone': 18000, 'id': 1499053, 'name': 'Megion', 'cod': 200}
# Processing Record 50 of Set 15 | tumannyy
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 1 of Set 16 | antibes
# {'coord': {'lon': 7.1278, 'lat': 43.5624}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 61.77, 'feels_like': 61.5, 'temp_min': 56.66, 'temp_max': 64.15, 'pressure': 1026, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 330}, 'clouds': {'all': 0}, 'dt': 1665023431, 'sys': {'type': 1, 'id': 6515, 'country': 'FR', 'sunrise': 1665034461, 'sunset': 1665075884}, 'timezone': 7200, 'id': 3037456, 'name': 'Antibes', 'cod': 200}
# Processing Record 2 of Set 16 | kegayli
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 3 of Set 16 | badiraguato
# {'coord': {'lon': -107.5167, 'lat': 25.3667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 72.18, 'feels_like': 72.95, 'temp_min': 72.18, 'temp_max': 72.18, 'pressure': 1013, 'humidity': 82, 'sea_level': 1013, 'grnd_level': 983}, 'visibility': 10000, 'wind': {'speed': 2.51, 'deg': 6, 'gust': 2.98}, 'clouds': {'all': 4}, 'dt': 1665023432, 'sys': {'country': 'MX', 'sunrise': 1664975028, 'sunset': 1665017570}, 'timezone': -21600, 'id': 4017743, 'name': 'Badiraguato', 'cod': 200}
# Processing Record 4 of Set 16 | casma
# {'coord': {'lon': -73.1244, 'lat': -41.0082}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 47.26, 'feels_like': 43.59, 'temp_min': 47.25, 'temp_max': 47.8, 'pressure': 1017, 'humidity': 99, 'sea_level': 1017, 'grnd_level': 1003}, 'visibility': 7302, 'wind': {'speed': 7.63, 'deg': 17, 'gust': 23.91}, 'clouds': {'all': 100}, 'dt': 1665023432, 'sys': {'type': 2, 'id': 2042158, 'country': 'CL', 'sunrise': 1664965179, 'sunset': 1665010915}, 'timezone': -10800, 'id': 3896281, 'name': 'Casma', 'cod': 200}
# Processing Record 5 of Set 16 | kanye
# {'coord': {'lon': 25.3327, 'lat': -24.9667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 65.52, 'feels_like': 63.88, 'temp_min': 65.52, 'temp_max': 65.52, 'pressure': 1015, 'humidity': 45, 'sea_level': 1015, 'grnd_level': 863}, 'visibility': 10000, 'wind': {'speed': 10.85, 'deg': 36, 'gust': 22.79}, 'clouds': {'all': 0}, 'dt': 1665023433, 'sys': {'country': 'BW', 'sunrise': 1665028415, 'sunset': 1665073193}, 'timezone': 7200, 'id': 933685, 'name': 'Kanye', 'cod': 200}
# Processing Record 6 of Set 16 | albuquerque
# {'coord': {'lon': -106.6511, 'lat': 35.0845}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 56.35, 'feels_like': 55.69, 'temp_min': 53.94, 'temp_max': 58.1, 'pressure': 1026, 'humidity': 85}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 70}, 'rain': {'1h': 0.2}, 'clouds': {'all': 100}, 'dt': 1665023207, 'sys': {'type': 2, 'id': 2006845, 'country': 'US', 'sunrise': 1664975062, 'sunset': 1665017121}, 'timezone': -21600, 'id': 5454711, 'name': 'Albuquerque', 'cod': 200}
# Processing Record 7 of Set 16 | aflu
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 8 of Set 16 | luau
# {'coord': {'lon': 22.2247, 'lat': -10.7073}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 66.74, 'feels_like': 66.54, 'temp_min': 66.74, 'temp_max': 66.74, 'pressure': 1011, 'humidity': 73, 'sea_level': 1011, 'grnd_level': 890}, 'visibility': 10000, 'wind': {'speed': 4.36, 'deg': 333, 'gust': 10.92}, 'clouds': {'all': 89}, 'dt': 1665023433, 'sys': {'country': 'AO', 'sunrise': 1665029515, 'sunset': 1665073584}, 'timezone': 3600, 'id': 876177, 'name': 'Luau', 'cod': 200}
# Processing Record 9 of Set 16 | iskilip
# {'coord': {'lon': 34.4739, 'lat': 40.7353}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 52.7, 'feels_like': 51.24, 'temp_min': 52.7, 'temp_max': 52.7, 'pressure': 1025, 'humidity': 76, 'sea_level': 1025, 'grnd_level': 938}, 'visibility': 10000, 'wind': {'speed': 6.51, 'deg': 23, 'gust': 8.75}, 'clouds': {'all': 90}, 'dt': 1665023434, 'sys': {'country': 'TR', 'sunrise': 1665027795, 'sunset': 1665069426}, 'timezone': 10800, 'id': 745076, 'name': 'İskilip', 'cod': 200}
# Processing Record 10 of Set 16 | leh
# {'coord': {'lon': 77.5833, 'lat': 34.1667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 44.1, 'feels_like': 41.94, 'temp_min': 44.1, 'temp_max': 44.1, 'pressure': 1018, 'humidity': 50, 'sea_level': 1018, 'grnd_level': 675}, 'visibility': 10000, 'wind': {'speed': 4.14, 'deg': 249, 'gust': 5.53}, 'clouds': {'all': 0}, 'dt': 1665023223, 'sys': {'country': 'IN', 'sunrise': 1665017243, 'sunset': 1665059289}, 'timezone': 19800, 'id': 1264976, 'name': 'Leh', 'cod': 200}
# Processing Record 11 of Set 16 | santa cruz de la palma
# {'coord': {'lon': -17.7642, 'lat': 28.6835}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 73.54, 'feels_like': 74.03, 'temp_min': 73.54, 'temp_max': 76.14, 'pressure': 1022, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 360}, 'clouds': {'all': 0}, 'dt': 1665023434, 'sys': {'type': 1, 'id': 2377, 'country': 'ES', 'sunrise': 1665039990, 'sunset': 1665082300}, 'timezone': 3600, 'id': 2511180, 'name': 'Santa Cruz de La Palma', 'cod': 200}
# Processing Record 12 of Set 16 | boyolangu
# {'coord': {'lon': 111.8935, 'lat': -8.1181}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 78.53, 'feels_like': 79.93, 'temp_min': 78.53, 'temp_max': 78.53, 'pressure': 1013, 'humidity': 82, 'sea_level': 1013, 'grnd_level': 1002}, 'visibility': 10000, 'wind': {'speed': 9.08, 'deg': 165, 'gust': 11.9}, 'clouds': {'all': 100}, 'dt': 1665023435, 'sys': {'country': 'ID', 'sunrise': 1665008061, 'sunset': 1665052006}, 'timezone': 25200, 'id': 1648082, 'name': 'Boyolangu', 'cod': 200}
# Processing Record 13 of Set 16 | iaciara
# {'coord': {'lon': -46.6317, 'lat': -14.0958}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 79.68, 'feels_like': 79.68, 'temp_min': 79.68, 'temp_max': 79.68, 'pressure': 1011, 'humidity': 48, 'sea_level': 1011, 'grnd_level': 947}, 'visibility': 10000, 'wind': {'speed': 2.48, 'deg': 175, 'gust': 6.29}, 'clouds': {'all': 40}, 'dt': 1665023435, 'sys': {'country': 'BR', 'sunrise': 1664959596, 'sunset': 1665003784}, 'timezone': -10800, 'id': 3461641, 'name': 'Iaciara', 'cod': 200}
# Processing Record 14 of Set 16 | camana
# {'coord': {'lon': -72.7111, 'lat': -16.6228}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 59.86, 'feels_like': 59.4, 'temp_min': 59.86, 'temp_max': 59.86, 'pressure': 1017, 'humidity': 82, 'sea_level': 1017, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 11.7, 'deg': 127, 'gust': 12.75}, 'clouds': {'all': 13}, 'dt': 1665023436, 'sys': {'country': 'PE', 'sunrise': 1664965795, 'sunset': 1665010100}, 'timezone': -18000, 'id': 3945985, 'name': 'Camaná', 'cod': 200}
# Processing Record 15 of Set 16 | teknaf
# {'coord': {'lon': 92.3058, 'lat': 20.8624}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 84.52, 'feels_like': 91.62, 'temp_min': 84.52, 'temp_max': 84.52, 'pressure': 1012, 'humidity': 70, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 1.57, 'deg': 130, 'gust': 1.61}, 'clouds': {'all': 34}, 'dt': 1665023436, 'sys': {'country': 'BD', 'sunrise': 1665013378, 'sunset': 1665056090}, 'timezone': 21600, 'id': 1185095, 'name': 'Teknāf', 'cod': 200}
# Processing Record 16 of Set 16 | mehamn
# {'coord': {'lon': 27.8492, 'lat': 71.0357}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 42.75, 'feels_like': 39.99, 'temp_min': 40.91, 'temp_max': 42.75, 'pressure': 993, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 0}, 'clouds': {'all': 100}, 'dt': 1665023437, 'sys': {'type': 1, 'id': 1633, 'country': 'NO', 'sunrise': 1665031553, 'sunset': 1665068847}, 'timezone': 7200, 'id': 778707, 'name': 'Mehamn', 'cod': 200}
# Processing Record 17 of Set 16 | palampur
# {'coord': {'lon': 76.5333, 'lat': 32.1167}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 69.01, 'feels_like': 68.38, 'temp_min': 69.01, 'temp_max': 69.01, 'pressure': 1014, 'humidity': 59, 'sea_level': 1014, 'grnd_level': 876}, 'visibility': 10000, 'wind': {'speed': 2.01, 'deg': 250, 'gust': 2.44}, 'clouds': {'all': 1}, 'dt': 1665023437, 'sys': {'country': 'IN', 'sunrise': 1665017439, 'sunset': 1665059597}, 'timezone': 19800, 'id': 1260784, 'name': 'Pālampur', 'cod': 200}
# Processing Record 18 of Set 16 | visnes
# {'coord': {'lon': 5.2242, 'lat': 59.3556}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 53.67, 'feels_like': 52.07, 'temp_min': 52.83, 'temp_max': 55.22, 'pressure': 1000, 'humidity': 71}, 'visibility': 10000, 'wind': {'speed': 26.46, 'deg': 240}, 'clouds': {'all': 20}, 'dt': 1665023437, 'sys': {'type': 1, 'id': 1631, 'country': 'NO', 'sunrise': 1665035707, 'sunset': 1665075550}, 'timezone': 7200, 'id': 3131500, 'name': 'Visnes', 'cod': 200}
# Processing Record 19 of Set 16 | leshukonskoye
# {'coord': {'lon': 45.7622, 'lat': 64.8989}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 44.15, 'feels_like': 42.78, 'temp_min': 44.15, 'temp_max': 44.15, 'pressure': 1012, 'humidity': 97, 'sea_level': 1012, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 3.27, 'deg': 165, 'gust': 6.78}, 'clouds': {'all': 100}, 'dt': 1665023277, 'sys': {'country': 'RU', 'sunrise': 1665026430, 'sunset': 1665065373}, 'timezone': 10800, 'id': 535839, 'name': 'Leshukonskoye', 'cod': 200}
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 716

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       acapulco  16.8634  -99.8901     82.22        74          75
# 1     chokurdakh  70.6333  147.9167     21.40        89          97
# 2    provideniya  64.3833 -173.3000     41.36       100         100
# 3  berdigestyakh  62.0989  126.6992     29.62        88         100
# 4      busselton -33.6500  115.3333     57.42        62          89
# 5        whyalla -33.0333  137.5833     78.69        29          75
# 6    bodden town  19.2833  -81.2500     84.20        75          75
# 7         namibe -15.1961   12.1522     62.01        90          50
# 8        qaanaaq  77.4840  -69.3632      5.25        70          35
# 9       coquimbo -29.9533  -71.3436     55.13        94           0
#
#    Wind Speed Country                 Date          Current Description
# 0        8.05      MX  2022-10-06 02:08:49                broken clouds
# 1        8.10      RU  2022-10-06 02:11:00              overcast clouds
# 2       40.00      RU  2022-10-06 02:11:00  light intensity shower rain
# 3        6.85      RU  2022-10-06 02:11:00                   light snow
# 4       14.47      AU  2022-10-06 02:11:01              overcast clouds
# 5       17.27      AU  2022-10-06 02:11:01                broken clouds
# 6        6.91      KY  2022-10-06 02:09:23                broken clouds
# 7        7.61      AO  2022-10-06 02:11:02             scattered clouds
# 8        7.92      GL  2022-10-06 02:11:02             scattered clouds
# 9        2.30      CL  2022-10-06 02:07:51                    clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       acapulco      MX  16.8634  -99.8901     82.22        74          75
# 1     chokurdakh      RU  70.6333  147.9167     21.40        89          97
# 2    provideniya      RU  64.3833 -173.3000     41.36       100         100
# 3  berdigestyakh      RU  62.0989  126.6992     29.62        88         100
# 4      busselton      AU -33.6500  115.3333     57.42        62          89
# 5        whyalla      AU -33.0333  137.5833     78.69        29          75
# 6    bodden town      KY  19.2833  -81.2500     84.20        75          75
# 7         namibe      AO -15.1961   12.1522     62.01        90          50
# 8        qaanaaq      GL  77.4840  -69.3632      5.25        70          35
# 9       coquimbo      CL -29.9533  -71.3436     55.13        94           0
#
#    Wind Speed          Current Description
# 0        8.05                broken clouds
# 1        8.10              overcast clouds
# 2       40.00  light intensity shower rain
# 3        6.85                   light snow
# 4       14.47              overcast clouds
# 5       17.27                broken clouds
# 6        6.91                broken clouds
# 7        7.61             scattered clouds
# 8        7.92             scattered clouds
# 9        2.30                    clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
